# %% [raw]
# ---
# description: Linux User, Groups and Permissions
# output-file: linux_users.html
# skip_exec: true
# skip_showdoc: true
# title: Linux Users, Groups and Permissions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
