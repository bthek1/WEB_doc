# %% [raw]
# ---
# description: For auto load and unloading environments
# output-file: direnv.html
# skip_exec: true
# skip_showdoc: true
# title: Direnv
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```bash
# sudo apt-get install direnv
# ```

# %% [markdown]
# ## Configure Your Shell

# %% [markdown]
# > Add to bash
# ```sh
# eval "$(direnv hook bash)"
# ```
#
# > Reload bash
# ```sh
# source ~/.bashrc
# ```

# %% [markdown]
# ## Create a .envrc File in Your Project Directory
#
# > Navigate to your project directory and create a .envrc file:

# %% [markdown]
# ```bash
# cd /path/to/your/project
# echo 'export POETRY_ACTIVE=1' > .envrc
# echo 'source "$(poetry env info --path)/bin/activate"' >> .envrc
#
# ```

# %% [markdown]
# ## Allow the .envrc File

# %% [markdown]
# ```bash
# direnv allow
#
# ```
