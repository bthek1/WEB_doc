# %% [raw]
# ---
# description: Preconfigured Django
# output-file: django_x.html
# skip_exec: true
# skip_showdoc: true
# title: DjangoX
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# - Use template
#
#
# TODO: update template
