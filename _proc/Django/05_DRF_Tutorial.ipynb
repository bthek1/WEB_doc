# %% [raw]
# ---
# description: DRF Tutorial
# output-file: drf_tutorial.html
# skip_exec: true
# skip_showdoc: true
# title: DRF Tutorial
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Getting started

# %% [markdown]
# ```bash
# django-admin startproject tut2
# cd tut2
# python manage.py startapp snippets
# ```

# %% [markdown]
# ## tutorial/settings.py

# %% [markdown]
# ```bash
# INSTALLED_APPS = [
#     ...
#     'rest_framework',
#     'snippets',
# ]
# ```
