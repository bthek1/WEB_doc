# %% [raw]
# ---
# description: Wireshark
# output-file: wireshark.html
# skip_exec: true
# skip_showdoc: true
# title: Wireshark
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# sudo apt install wireshark
#
# ```
