# %% [raw]
# ---
# description: high performance web server and a reverse proxy server
# output-file: nginx.html
# title: Nginx
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Features

# %% [markdown]
# - Admin site
# - Object-relational mapper
# - Authentication
# - Caching

# %% [markdown]
# `HTTP` : Hypertext Transfer Protocol

# %% [markdown]
# ## Installation

# %% [markdown]
# ```sh
# sudo apt update
# sudo apt install nginx
# ```

# %% [markdown]
# ## Start

# %% [markdown]
# ```sh
# sudo systemctl start nginx
# ```

# %% [markdown]
# ## Status

# %% [markdown]
# ```sh
# sudo systemctl status nginx
# ```

# %% [markdown]
# ## Stop

# %% [markdown]
# ```sh
# sudo systemctl stop nginx
# ```

# %% [markdown]
# ## Reload

# %% [markdown]
# ```sh
# sudo nginx -s reload
# ```

# %% [markdown]
# ## Default html file in

# %% [markdown]
# ```sh
# cd /var/www/html
# ```

# %% [markdown]
# ## Nginx

# %% [markdown]
# ```sh
# cd /etc/nginx/sites-enables
# ```
